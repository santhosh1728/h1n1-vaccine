# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/h1n1_vaccine_prediction.csv")

# %%
# # We need to tell whether the respondent received H1N1 flu vaccine or not
# ### hence it is a Classification problem because it says vaccine is received or not
#

# %%
# ## Data Visualizing

# %%
data.shape
# Out:
# (26707, 34)

# %%
data.tail(20)
# Out:
#        unique_id  h1n1_worry  h1n1_awareness  antiviral_medication  \
# 26687      26687         3.0             2.0                   0.0
# 26688      26688         2.0             2.0                   0.0
# 26689      26689         2.0             1.0                   0.0
# 26690      26690         0.0             2.0                   0.0
# 26691      26691         2.0             2.0                   0.0
# 26692      26692         1.0             1.0                   0.0
# 26693      26693         1.0             1.0                   1.0
# 26694      26694         2.0             2.0                   0.0
# 26695      26695         0.0             0.0                   0.0
# 26696      26696         2.0             1.0                   0.0
# 26697      26697         1.0             1.0                   0.0
# 26698      26698         2.0             1.0                   0.0
# 26699      26699         2.0             2.0                   0.0
# 26700      26700         3.0             1.0                   0.0
# 26701      26701         2.0             2.0                   0.0
# 26702      26702         2.0             0.0                   0.0
# 26703      26703         1.0             2.0                   0.0
# 26704      26704         2.0             2.0                   0.0
# 26705      26705         1.0             1.0                   0.0
# 26706      26706         0.0             0.0                   0.0
#
#        contact_avoidance  bought_face_mask  wash_hands_frequently  \
# 26687                NaN               1.0                    1.0
# 26688                1.0               0.0                    1.0
# 26689                1.0               0.0                    0.0
# 26690                0.0               0.0                    1.0
# 26691                1.0               1.0                    1.0
# 26692                0.0               0.0                    1.0
# 26693                1.0               0.0                    1.0
# 26694                1.0               0.0                    1.0
# 26695                0.0               0.0                    0.0
# 26696                1.0               0.0                    1.0
# 26697                1.0               0.0                    1.0
# 26698                1.0               0.0                    1.0
# 26699                1.0               0.0                    1.0
# 26700                1.0               0.0                    1.0
# 26701                0.0               0.0                    1.0
# 26702                1.0               0.0                    0.0
# 26703                1.0               0.0                    1.0
# 26704                1.0               1.0                    1.0
# 26705                0.0               0.0                    0.0
# 26706                1.0               0.0                    0.0
#
#        avoid_large_gatherings  reduced_outside_home_cont  avoid_touch_face  \
# 26687                     0.0                        0.0               1.0
# 26688                     0.0                        0.0               1.0
# 26689                     1.0                        1.0               1.0
# 26690                     0.0                        0.0               1.0
# 26691                     0.0                        0.0               1.0
# 26692                     0.0                        0.0               1.0
# 26693                     0.0                        1.0               1.0
# 26694                     0.0                        0.0               1.0
# 26695                     0.0                        0.0               0.0
# 26696                     0.0                        1.0               1.0
# 26697                     0.0                        1.0               1.0
# 26698                     0.0                        0.0               1.0
# 26699                     1.0                        0.0               1.0
# 26700                     0.0                        0.0               1.0
# 26701                     0.0                        0.0               1.0
# 26702                     0.0                        1.0               0.0
# 26703                     0.0                        0.0               0.0
# 26704                     1.0                        0.0               1.0
# 26705                     0.0                        0.0               NaN
# 26706                     0.0                        0.0               0.0
#
#        ...      race     sex               income_level  marital_status  \
# 26687  ...     White  Female  <= $75,000, Above Poverty     Not Married
# 26688  ...     White    Male  <= $75,000, Above Poverty     Not Married
# 26689  ...     Black    Male                  > $75,000         Married
# 26690  ...  Hispanic  Female  <= $75,000, Above Poverty         Married
# 26691  ...     White  Female                  > $75,000         Married
# 26692  ...     White  Female              Below Poverty     Not Married
# 26693  ...     White  Female  <= $75,000, Above Poverty         Married
# 26694  ...     White  Female                  > $75,000     Not Married
# 26695  ...     White    Male                  > $75,000     Not Married
# 26696  ...     White    Male                        NaN         Married
# 26697  ...     White    Male                  > $75,000         Married
# 26698  ...     White  Female                  > $75,000         Married
# 26699  ...     White  Female  <= $75,000, Above Poverty         Married
# 26700  ...     White  Female                  > $75,000         Married
# 26701  ...     White  Female                  > $75,000     Not Married
# 26702  ...     White  Female  <= $75,000, Above Poverty     Not Married
# 26703  ...     White    Male  <= $75,000, Above Poverty     Not Married
# 26704  ...     White  Female                        NaN     Not Married
# 26705  ...  Hispanic  Female  <= $75,000, Above Poverty         Married
# 26706  ...     White    Male  <= $75,000, Above Poverty         Married
#
#        housing_status          employment                census_msa  \
# 26687             Own  Not in Labor Force  MSA, Not Principle  City
# 26688            Rent  Not in Labor Force  MSA, Not Principle  City
# 26689             Own            Employed  MSA, Not Principle  City
# 26690             Own            Employed       MSA, Principle City
# 26691            Rent            Employed  MSA, Not Principle  City
# 26692            Rent            Employed                   Non-MSA
# 26693             Own  Not in Labor Force                   Non-MSA
# 26694             Own            Employed  MSA, Not Principle  City
# 26695            Rent            Employed       MSA, Principle City
# 26696             Own            Employed       MSA, Principle City
# 26697             Own  Not in Labor Force       MSA, Principle City
# 26698             Own            Employed  MSA, Not Principle  City
# 26699             Own            Employed  MSA, Not Principle  City
# 26700             Own  Not in Labor Force       MSA, Principle City
# 26701            Rent  Not in Labor Force       MSA, Principle City
# 26702             Own  Not in Labor Force                   Non-MSA
# 26703            Rent            Employed       MSA, Principle City
# 26704             Own                 NaN  MSA, Not Principle  City
# 26705            Rent            Employed                   Non-MSA
# 26706             Own  Not in Labor Force       MSA, Principle City
#
#        no_of_adults  no_of_children  h1n1_vaccine
# 26687           0.0             0.0             0
# 26688           0.0             0.0             1
# 26689           1.0             3.0             0
# 26690           2.0             1.0             0
# 26691           0.0             0.0             0
# 26692           1.0             2.0             0
# 26693           1.0             0.0             0
# 26694           0.0             0.0             0
# 26695           0.0             0.0             0
# 26696           1.0             0.0             1
# 26697           1.0             0.0             0
# 26698           1.0             1.0             0
# 26699           1.0             0.0             0
# 26700           1.0             0.0             0
# 26701           3.0             0.0             0
# 26702           0.0             0.0             0
# 26703           1.0             0.0             0
# 26704           0.0             0.0             0
# 26705           1.0             0.0             0
# 26706           1.0             0.0             0
#
# [20 rows x 34 columns]

# %%
duplicate=data.duplicated()
print(duplicate.sum())
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data.hist(figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'unique_id'}>,
#         <AxesSubplot:title={'center':'h1n1_worry'}>,
#         <AxesSubplot:title={'center':'h1n1_awareness'}>,
#         <AxesSubplot:title={'center':'antiviral_medication'}>,
#         <AxesSubplot:title={'center':'contact_avoidance'}>],
#        [<AxesSubplot:title={'center':'bought_face_mask'}>,
#         <AxesSubplot:title={'center':'wash_hands_frequently'}>,
#         <AxesSubplot:title={'center':'avoid_large_gatherings'}>,
#         <AxesSubplot:title={'center':'reduced_outside_home_cont'}>,
#         <AxesSubplot:title={'center':'avoid_touch_face'}>],
#        [<AxesSubplot:title={'center':'dr_recc_h1n1_vacc'}>,
#         <AxesSubplot:title={'center':'dr_recc_seasonal_vacc'}>,
#         <AxesSubplot:title={'center':'chronic_medic_condition'}>,
#         <AxesSubplot:title={'center':'cont_child_undr_6_mnths'}>,
#         <AxesSubplot:title={'center':'is_health_worker'}>],
#        [<AxesSubplot:title={'center':'has_health_insur'}>,
#         <AxesSubplot:title={'center':'is_h1n1_vacc_effective'}>,
#         <AxesSubplot:title={'center':'is_h1n1_risky'}>,
#         <AxesSubplot:title={'center':'sick_from_h1n1_vacc'}>,
#         <AxesSubplot:title={'center':'is_seas_vacc_effective'}>],
#        [<AxesSubplot:title={'center':'is_seas_risky'}>,
#         <AxesSubplot:title={'center':'sick_from_seas_vacc'}>,
#         <AxesSubplot:title={'center':'no_of_adults'}>,
#         <AxesSubplot:title={'center':'no_of_children'}>,
#         <AxesSubplot:title={'center':'h1n1_vaccine'}>]], dtype=object)

# %%
# ## Data cleaning

# ### Here 0:not vaccinated ; 1: vaccinated

# %%
data["h1n1_vaccine"].value_counts()
# Out:
# 0    21033
# 1     5674
# Name: h1n1_vaccine, dtype: int64

# %%
data.groupby("h1n1_vaccine").mean()
# Out:
#                  unique_id  h1n1_worry  h1n1_awareness  antiviral_medication  \
# h1n1_vaccine
# 0             13366.133885    1.560815        1.224653              0.044305
# 1             13304.313888    1.832096        1.402866              0.065722
#
#               contact_avoidance  bought_face_mask  wash_hands_frequently  \
# h1n1_vaccine
# 0                      0.714546          0.059705               0.810887
# 1                      0.766531          0.103387               0.880184
#
#               avoid_large_gatherings  reduced_outside_home_cont  \
# h1n1_vaccine
# 0                           0.354198                   0.331966
# 1                           0.375088                   0.357118
#
#               avoid_touch_face  ...  is_health_worker  has_health_insur  \
# h1n1_vaccine                    ...
# 0                     0.659848  ...          0.084033          0.854087
# 1                     0.741690  ...          0.214647          0.940326
#
#               is_h1n1_vacc_effective  is_h1n1_risky  sick_from_h1n1_vacc  \
# h1n1_vaccine
# 0                           3.709576       2.126815             2.304503
# 1                           4.372633       3.142985             2.554622
#
#               is_seas_vacc_effective  is_seas_risky  sick_from_seas_vacc  \
# h1n1_vaccine
# 0                           3.924745       2.533000             2.112314
# 1                           4.400752       3.408112             2.139527
#
#               no_of_adults  no_of_children
# h1n1_vaccine
# 0                 0.883542        0.536186
# 1                 0.897427        0.528660
#
# [2 rows x 24 columns]

# %%
data.isnull().sum()
# Out:
# unique_id                        0
# h1n1_worry                      92
# h1n1_awareness                 116
# antiviral_medication            71
# contact_avoidance              208
# bought_face_mask                19
# wash_hands_frequently           42
# avoid_large_gatherings          87
# reduced_outside_home_cont       82
# avoid_touch_face               128
# dr_recc_h1n1_vacc             2160
# dr_recc_seasonal_vacc         2160
# chronic_medic_condition        971
# cont_child_undr_6_mnths        820
# is_health_worker               804
# has_health_insur             12274
# is_h1n1_vacc_effective         391
# is_h1n1_risky                  388
# sick_from_h1n1_vacc            395
# is_seas_vacc_effective         462
# is_seas_risky                  514
# sick_from_seas_vacc            537
# age_bracket                      0
# qualification                 1407
# race                             0
# sex                              0
# income_level                  4423
# marital_status                1408
# housing_status                2042
# employment                    1463
# census_msa                       0
# no_of_adults                   249
# no_of_children                 249
# h1n1_vaccine                     0
# dtype: int64

# %%
null_var=data.isnull().sum()/data.shape[0]*1000
null_var
# Out:
# unique_id                      0.000000
# h1n1_worry                     3.444790
# h1n1_awareness                 4.343431
# antiviral_medication           2.658479
# contact_avoidance              7.788220
# bought_face_mask               0.711424
# wash_hands_frequently          1.572621
# avoid_large_gatherings         3.257573
# reduced_outside_home_cont      3.070356
# avoid_touch_face               4.792751
# dr_recc_h1n1_vacc             80.877673
# dr_recc_seasonal_vacc         80.877673
# chronic_medic_condition       36.357509
# cont_child_undr_6_mnths       30.703561
# is_health_worker              30.104467
# has_health_insur             459.579885
# is_h1n1_vacc_effective        14.640356
# is_h1n1_risky                 14.528026
# sick_from_h1n1_vacc           14.790130
# is_seas_vacc_effective        17.298836
# is_seas_risky                 19.245891
# sick_from_seas_vacc           20.107088
# age_bracket                    0.000000
# qualification                 52.682817
# race                           0.000000
# sex                            0.000000
# income_level                 165.612012
# marital_status                52.720261
# housing_status                76.459355
# employment                    54.779646
# census_msa                     0.000000
# no_of_adults                   9.323398
# no_of_children                 9.323398
# h1n1_vaccine                   0.000000
# dtype: float64

# %%
data.dtypes
# Out:
# unique_id                      int64
# h1n1_worry                   float64
# h1n1_awareness               float64
# antiviral_medication         float64
# contact_avoidance            float64
# bought_face_mask             float64
# wash_hands_frequently        float64
# avoid_large_gatherings       float64
# reduced_outside_home_cont    float64
# avoid_touch_face             float64
# dr_recc_h1n1_vacc            float64
# dr_recc_seasonal_vacc        float64
# chronic_medic_condition      float64
# cont_child_undr_6_mnths      float64
# is_health_worker             float64
# has_health_insur             float64
# is_h1n1_vacc_effective       float64
# is_h1n1_risky                float64
# sick_from_h1n1_vacc          float64
# is_seas_vacc_effective       float64
# is_seas_risky                float64
# sick_from_seas_vacc          float64
# age_bracket                   object
# qualification                 object
# race                          object
# sex                           object
# income_level                  object
# marital_status                object
# housing_status                object
# employment                    object
# census_msa                    object
# no_of_adults                 float64
# no_of_children               float64
# h1n1_vaccine                   int64
# dtype: object

# %%
drop_columns=null_var[null_var>50].keys()
drop_columns
# Out:
# Index(['dr_recc_h1n1_vacc', 'dr_recc_seasonal_vacc', 'has_health_insur',
#        'qualification', 'income_level', 'marital_status', 'housing_status',
#        'employment'],
#       dtype='object')

# %%
data.drop(['dr_recc_h1n1_vacc', 'dr_recc_seasonal_vacc', 'has_health_insur',
       'qualification', 'income_level', 'marital_status', 'housing_status',
       'employment'],axis=1,inplace=True)

# %%
data.drop('unique_id',axis=1,inplace=True)

# %%
data["age_bracket"]=data["age_bracket"].replace({1:"65+ Years", 2:"18 - 34 Years", 3:"55 - 64 Years",4:"35 - 44 Years", 5:"45 - 54 Years"})
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 10252         3.0             0.0                   0.0                1.0
# 19619         1.0             1.0                   0.0                1.0
# 18088         1.0             2.0                   0.0                0.0
# 12364         2.0             1.0                   0.0                1.0
# 22301         3.0             1.0                   0.0                1.0
# 21691         2.0             1.0                   0.0                0.0
# 17253         2.0             2.0                   0.0                0.0
# 12441         2.0             2.0                   0.0                0.0
# 6103          2.0             2.0                   1.0                1.0
# 4255          0.0             2.0                   0.0                1.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 10252               0.0                    1.0                     0.0
# 19619               0.0                    0.0                     0.0
# 18088               0.0                    1.0                     0.0
# 12364               0.0                    1.0                     0.0
# 22301               0.0                    1.0                     1.0
# 21691               0.0                    1.0                     0.0
# 17253               0.0                    1.0                     1.0
# 12441               0.0                    1.0                     0.0
# 6103                0.0                    1.0                     1.0
# 4255                1.0                    1.0                     1.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 10252                        0.0               1.0                      0.0
# 19619                        0.0               0.0                      0.0
# 18088                        0.0               1.0                      0.0
# 12364                        0.0               1.0                      0.0
# 22301                        1.0               1.0                      1.0
# 21691                        0.0               0.0                      0.0
# 17253                        1.0               1.0                      0.0
# 12441                        0.0               1.0                      0.0
# 6103                         1.0               1.0                      0.0
# 4255                         1.0               1.0                      0.0
#
#        ...  is_seas_vacc_effective  is_seas_risky  sick_from_seas_vacc  \
# 10252  ...                     5.0            2.0                  2.0
# 19619  ...                     3.0            2.0                  4.0
# 18088  ...                     5.0            4.0                  1.0
# 12364  ...                     4.0            4.0                  1.0
# 22301  ...                     4.0            2.0                  2.0
# 21691  ...                     4.0            4.0                  1.0
# 17253  ...                     5.0            4.0                  2.0
# 12441  ...                     5.0            4.0                  1.0
# 6103   ...                     5.0            1.0                  1.0
# 4255   ...                     2.0            4.0                  4.0
#
#          age_bracket               race     sex                census_msa  \
# 10252  18 - 34 Years  Other or Multiple  Female  MSA, Not Principle  City
# 19619  18 - 34 Years              White    Male       MSA, Principle City
# 18088  55 - 64 Years              White  Female  MSA, Not Principle  City
# 12364  45 - 54 Years              White  Female  MSA, Not Principle  City
# 22301      65+ Years              White  Female                   Non-MSA
# 21691  55 - 64 Years              White  Female                   Non-MSA
# 17253      65+ Years              White  Female       MSA, Principle City
# 12441      65+ Years              White  Female       MSA, Principle City
# 6103   45 - 54 Years              White  Female                   Non-MSA
# 4255   18 - 34 Years              White    Male  MSA, Not Principle  City
#
#        no_of_adults no_of_children h1n1_vaccine
# 10252           2.0            2.0            0
# 19619           3.0            0.0            0
# 18088           1.0            0.0            0
# 12364           1.0            0.0            0
# 22301           1.0            0.0            0
# 21691           1.0            0.0            0
# 17253           0.0            0.0            1
# 12441           1.0            0.0            1
# 6103            0.0            0.0            1
# 4255            3.0            2.0            0
#
# [10 rows x 25 columns]

# %%
data=pd.get_dummies(data,columns=["age_bracket"])
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 2144          2.0             1.0                   0.0                1.0
# 25426         0.0             0.0                   0.0                0.0
# 22899         1.0             1.0                   0.0                0.0
# 24068         1.0             1.0                   0.0                1.0
# 15219         3.0             2.0                   0.0                0.0
# 21043         1.0             1.0                   0.0                1.0
# 15604         0.0             1.0                   0.0                1.0
# 8311          3.0             1.0                   0.0                0.0
# 17553         3.0             1.0                   0.0                1.0
# 18985         1.0             1.0                   0.0                0.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 2144                0.0                    0.0                     0.0
# 25426               0.0                    0.0                     0.0
# 22899               0.0                    1.0                     1.0
# 24068               0.0                    1.0                     0.0
# 15219               1.0                    1.0                     1.0
# 21043               0.0                    1.0                     0.0
# 15604               0.0                    1.0                     0.0
# 8311                0.0                    1.0                     1.0
# 17553               0.0                    1.0                     0.0
# 18985               0.0                    1.0                     0.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 2144                         1.0               0.0                      0.0
# 25426                        0.0               0.0                      0.0
# 22899                        1.0               1.0                      1.0
# 24068                        0.0               0.0                      0.0
# 15219                        0.0               1.0                      0.0
# 21043                        0.0               1.0                      0.0
# 15604                        0.0               0.0                      1.0
# 8311                         0.0               1.0                      1.0
# 17553                        0.0               1.0                      0.0
# 18985                        0.0               1.0                      0.0
#
#        ...     sex                census_msa  no_of_adults  no_of_children  \
# 2144   ...  Female  MSA, Not Principle  City           0.0             1.0
# 25426  ...  Female                   Non-MSA           0.0             0.0
# 22899  ...  Female       MSA, Principle City           0.0             0.0
# 24068  ...    Male  MSA, Not Principle  City           2.0             0.0
# 15219  ...  Female       MSA, Principle City           1.0             1.0
# 21043  ...    Male  MSA, Not Principle  City           2.0             1.0
# 15604  ...  Female       MSA, Principle City           1.0             3.0
# 8311   ...  Female       MSA, Principle City           1.0             0.0
# 17553  ...  Female  MSA, Not Principle  City           1.0             0.0
# 18985  ...  Female       MSA, Principle City           2.0             0.0
#
#        h1n1_vaccine  age_bracket_18 - 34 Years  age_bracket_35 - 44 Years  \
# 2144              0                          0                          0
# 25426             0                          0                          0
# 22899             0                          0                          0
# 24068             0                          1                          0
# 15219             1                          0                          1
# 21043             0                          1                          0
# 15604             1                          1                          0
# 8311              0                          0                          0
# 17553             0                          0                          0
# 18985             0                          1                          0
#
#        age_bracket_45 - 54 Years age_bracket_55 - 64 Years  \
# 2144                           1                         0
# 25426                          0                         0
# 22899                          0                         0
# 24068                          0                         0
# 15219                          0                         0
# 21043                          0                         0
# 15604                          0                         0
# 8311                           0                         0
# 17553                          0                         0
# 18985                          0                         0
#
#       age_bracket_65+ Years
# 2144                      0
# 25426                     1
# 22899                     1
# 24068                     0
# 15219                     0
# 21043                     0
# 15604                     0
# 8311                      1
# 17553                     1
# 18985                     0
#
# [10 rows x 29 columns]

# %%
data["race"]=data["race"].replace({1:"White", 2:"Black", 3:"Hispanic",4:"Other or Multiple"})
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 6582          0.0             2.0                   0.0                1.0
# 6492          2.0             1.0                   0.0                1.0
# 2412          1.0             2.0                   0.0                0.0
# 23044         0.0             0.0                   0.0                0.0
# 13120         1.0             1.0                   0.0                1.0
# 1356          3.0             2.0                   0.0                1.0
# 2538          1.0             1.0                   0.0                1.0
# 13100         2.0             1.0                   0.0                1.0
# 10374         0.0             2.0                   0.0                0.0
# 18214         2.0             2.0                   0.0                1.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 6582                0.0                    1.0                     0.0
# 6492                0.0                    1.0                     1.0
# 2412                0.0                    1.0                     0.0
# 23044               0.0                    1.0                     0.0
# 13120               0.0                    1.0                     0.0
# 1356                0.0                    0.0                     1.0
# 2538                0.0                    0.0                     1.0
# 13100               0.0                    1.0                     0.0
# 10374               0.0                    0.0                     0.0
# 18214               0.0                    0.0                     0.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 6582                         0.0               1.0                      0.0
# 6492                         1.0               1.0                      0.0
# 2412                         0.0               1.0                      0.0
# 23044                        0.0               0.0                      0.0
# 13120                        0.0               1.0                      0.0
# 1356                         0.0               1.0                      0.0
# 2538                         0.0               0.0                      0.0
# 13100                        0.0               1.0                      0.0
# 10374                        0.0               0.0                      0.0
# 18214                        0.0               1.0                      1.0
#
#        ...     sex                census_msa  no_of_adults  no_of_children  \
# 6582   ...    Male       MSA, Principle City           1.0             2.0
# 6492   ...  Female       MSA, Principle City           0.0             0.0
# 2412   ...  Female  MSA, Not Principle  City           1.0             0.0
# 23044  ...    Male       MSA, Principle City           1.0             0.0
# 13120  ...  Female  MSA, Not Principle  City           1.0             0.0
# 1356   ...    Male  MSA, Not Principle  City           0.0             0.0
# 2538   ...    Male  MSA, Not Principle  City           3.0             1.0
# 13100  ...  Female                   Non-MSA           1.0             2.0
# 10374  ...  Female                   Non-MSA           1.0             0.0
# 18214  ...    Male  MSA, Not Principle  City           1.0             0.0
#
#        h1n1_vaccine  age_bracket_18 - 34 Years  age_bracket_35 - 44 Years  \
# 6582              0                          0                          0
# 6492              0                          0                          0
# 2412              0                          1                          0
# 23044             1                          0                          0
# 13120             0                          1                          0
# 1356              1                          0                          0
# 2538              0                          0                          0
# 13100             0                          1                          0
# 10374             0                          0                          0
# 18214             0                          0                          0
#
#        age_bracket_45 - 54 Years age_bracket_55 - 64 Years  \
# 6582                           1                         0
# 6492                           0                         0
# 2412                           0                         0
# 23044                          0                         0
# 13120                          0                         0
# 1356                           0                         0
# 2538                           1                         0
# 13100                          0                         0
# 10374                          0                         1
# 18214                          0                         0
#
#       age_bracket_65+ Years
# 6582                      0
# 6492                      1
# 2412                      0
# 23044                     1
# 13120                     0
# 1356                      1
# 2538                      0
# 13100                     0
# 10374                     0
# 18214                     1
#
# [10 rows x 29 columns]

# %%
data=pd.get_dummies(data,columns=["race"])
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 26127         2.0             2.0                   0.0                1.0
# 3058          3.0             1.0                   0.0                1.0
# 7666          2.0             1.0                   0.0                1.0
# 16450         0.0             1.0                   0.0                1.0
# 20121         2.0             2.0                   0.0                0.0
# 24833         0.0             2.0                   0.0                0.0
# 13202         1.0             NaN                   0.0                0.0
# 2090          2.0             1.0                   0.0                1.0
# 20143         0.0             0.0                   0.0                1.0
# 7874          2.0             1.0                   0.0                1.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 26127               0.0                    1.0                     0.0
# 3058                0.0                    1.0                     1.0
# 7666                0.0                    1.0                     0.0
# 16450               0.0                    1.0                     0.0
# 20121               0.0                    1.0                     1.0
# 24833               0.0                    1.0                     0.0
# 13202               0.0                    1.0                     0.0
# 2090                0.0                    1.0                     1.0
# 20143               0.0                    1.0                     1.0
# 7874                0.0                    1.0                     0.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 26127                        0.0               0.0                      1.0
# 3058                         0.0               1.0                      0.0
# 7666                         0.0               1.0                      0.0
# 16450                        0.0               1.0                      0.0
# 20121                        1.0               1.0                      0.0
# 24833                        0.0               0.0                      0.0
# 13202                        0.0               1.0                      NaN
# 2090                         1.0               1.0                      0.0
# 20143                        1.0               1.0                      0.0
# 7874                         0.0               0.0                      0.0
#
#        ...  h1n1_vaccine  age_bracket_18 - 34 Years  \
# 26127  ...             1                          0
# 3058   ...             1                          0
# 7666   ...             0                          0
# 16450  ...             0                          0
# 20121  ...             0                          0
# 24833  ...             0                          1
# 13202  ...             0                          0
# 2090   ...             0                          0
# 20143  ...             0                          0
# 7874   ...             0                          1
#
#        age_bracket_35 - 44 Years  age_bracket_45 - 54 Years  \
# 26127                          0                          1
# 3058                           0                          0
# 7666                           0                          1
# 16450                          0                          0
# 20121                          1                          0
# 24833                          0                          0
# 13202                          0                          0
# 2090                           0                          1
# 20143                          1                          0
# 7874                           0                          0
#
#        age_bracket_55 - 64 Years  age_bracket_65+ Years  race_Black  \
# 26127                          0                      0           0
# 3058                           0                      1           0
# 7666                           0                      0           0
# 16450                          1                      0           0
# 20121                          0                      0           0
# 24833                          0                      0           0
# 13202                          0                      1           0
# 2090                           0                      0           1
# 20143                          0                      0           0
# 7874                           0                      0           0
#
#        race_Hispanic race_Other or Multiple race_White
# 26127              1                      0          0
# 3058               0                      0          1
# 7666               0                      1          0
# 16450              0                      0          1
# 20121              1                      0          0
# 24833              0                      0          1
# 13202              0                      0          1
# 2090               0                      0          0
# 20143              0                      0          1
# 7874               1                      0          0
#
# [10 rows x 32 columns]

# %%
data["sex"]=data["sex"].replace({1:"Male", 2:"Female"})
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 8896          1.0             2.0                   0.0                0.0
# 848           3.0             1.0                   0.0                1.0
# 23113         1.0             2.0                   0.0                1.0
# 12598         2.0             2.0                   0.0                1.0
# 15859         3.0             1.0                   1.0                1.0
# 7294          1.0             1.0                   0.0                0.0
# 4392          3.0             1.0                   0.0                0.0
# 20098         2.0             1.0                   0.0                1.0
# 17920         0.0             1.0                   0.0                0.0
# 14825         3.0             2.0                   0.0                1.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 8896                0.0                    1.0                     0.0
# 848                 0.0                    1.0                     1.0
# 23113               0.0                    1.0                     0.0
# 12598               0.0                    1.0                     0.0
# 15859               0.0                    1.0                     0.0
# 7294                1.0                    1.0                     0.0
# 4392                0.0                    1.0                     1.0
# 20098               0.0                    1.0                     0.0
# 17920               0.0                    1.0                     0.0
# 14825               0.0                    1.0                     0.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 8896                         0.0               0.0                      0.0
# 848                          1.0               1.0                      0.0
# 23113                        0.0               1.0                      0.0
# 12598                        0.0               0.0                      0.0
# 15859                        1.0               1.0                      0.0
# 7294                         1.0               0.0                      0.0
# 4392                         1.0               1.0                      0.0
# 20098                        0.0               1.0                      0.0
# 17920                        0.0               0.0                      0.0
# 14825                        1.0               1.0                      0.0
#
#        ...  h1n1_vaccine  age_bracket_18 - 34 Years  \
# 8896   ...             0                          0
# 848    ...             0                          1
# 23113  ...             1                          1
# 12598  ...             1                          0
# 15859  ...             0                          1
# 7294   ...             1                          0
# 4392   ...             0                          0
# 20098  ...             0                          1
# 17920  ...             0                          1
# 14825  ...             0                          0
#
#        age_bracket_35 - 44 Years  age_bracket_45 - 54 Years  \
# 8896                           0                          1
# 848                            0                          0
# 23113                          0                          0
# 12598                          0                          0
# 15859                          0                          0
# 7294                           0                          1
# 4392                           0                          0
# 20098                          0                          0
# 17920                          0                          0
# 14825                          0                          1
#
#        age_bracket_55 - 64 Years  age_bracket_65+ Years  race_Black  \
# 8896                           0                      0           0
# 848                            0                      0           1
# 23113                          0                      0           0
# 12598                          1                      0           0
# 15859                          0                      0           1
# 7294                           0                      0           0
# 4392                           0                      1           1
# 20098                          0                      0           0
# 17920                          0                      0           0
# 14825                          0                      0           0
#
#        race_Hispanic race_Other or Multiple race_White
# 8896               0                      0          1
# 848                0                      0          0
# 23113              0                      0          1
# 12598              0                      0          1
# 15859              0                      0          0
# 7294               0                      0          1
# 4392               0                      0          0
# 20098              0                      0          1
# 17920              0                      0          1
# 14825              0                      0          1
#
# [10 rows x 32 columns]

# %%
data=pd.get_dummies(data,columns=["sex"])
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 7235          1.0             1.0                   0.0                1.0
# 22116         1.0             0.0                   0.0                1.0
# 18229         1.0             1.0                   0.0                1.0
# 12818         0.0             1.0                   0.0                0.0
# 16263         3.0             1.0                   0.0                1.0
# 15972         0.0             1.0                   0.0                0.0
# 378           2.0             1.0                   1.0                1.0
# 6208          1.0             1.0                   0.0                1.0
# 15924         2.0             1.0                   0.0                1.0
# 20450         0.0             0.0                   0.0                0.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 7235                0.0                    0.0                     0.0
# 22116               0.0                    1.0                     0.0
# 18229               0.0                    1.0                     0.0
# 12818               0.0                    1.0                     0.0
# 16263               0.0                    1.0                     0.0
# 15972               0.0                    0.0                     0.0
# 378                 0.0                    1.0                     1.0
# 6208                0.0                    1.0                     0.0
# 15924               0.0                    1.0                     0.0
# 20450               0.0                    0.0                     0.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 7235                         1.0               0.0                      0.0
# 22116                        0.0               0.0                      0.0
# 18229                        0.0               1.0                      0.0
# 12818                        0.0               1.0                      1.0
# 16263                        1.0               0.0                      1.0
# 15972                        0.0               0.0                      1.0
# 378                          1.0               1.0                      1.0
# 6208                         0.0               1.0                      1.0
# 15924                        0.0               1.0                      0.0
# 20450                        0.0               0.0                      0.0
#
#        ...  age_bracket_35 - 44 Years  age_bracket_45 - 54 Years  \
# 7235   ...                          0                          0
# 22116  ...                          0                          0
# 18229  ...                          0                          1
# 12818  ...                          0                          0
# 16263  ...                          0                          0
# 15972  ...                          0                          0
# 378    ...                          0                          0
# 6208   ...                          0                          0
# 15924  ...                          0                          0
# 20450  ...                          0                          0
#
#        age_bracket_55 - 64 Years  age_bracket_65+ Years  race_Black  \
# 7235                           0                      0           0
# 22116                          0                      0           0
# 18229                          0                      0           0
# 12818                          1                      0           0
# 16263                          1                      0           0
# 15972                          0                      0           0
# 378                            1                      0           0
# 6208                           1                      0           0
# 15924                          1                      0           0
# 20450                          0                      1           0
#
#        race_Hispanic  race_Other or Multiple  race_White sex_Female  sex_Male
# 7235               0                       0           1          0         1
# 22116              0                       0           1          1         0
# 18229              0                       0           1          1         0
# 12818              0                       0           1          1         0
# 16263              0                       0           1          1         0
# 15972              0                       0           1          0         1
# 378                0                       0           1          1         0
# 6208               0                       0           1          1         0
# 15924              0                       0           1          0         1
# 20450              0                       0           1          0         1
#
# [10 rows x 33 columns]

# %%
data["census_msa"]=data["census_msa"].replace({1:"Non-MSA", 2:"MSA, Principle City", 3:"MSA, Not Principle City"})
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 19818         2.0             1.0                   0.0                1.0
# 14734         1.0             2.0                   0.0                1.0
# 11098         1.0             2.0                   0.0                1.0
# 17360         1.0             1.0                   0.0                1.0
# 13678         1.0             2.0                   0.0                1.0
# 9650          1.0             1.0                   0.0                1.0
# 11341         2.0             2.0                   0.0                1.0
# 10066         3.0             2.0                   0.0                1.0
# 810           0.0             1.0                   0.0                1.0
# 937           1.0             2.0                   0.0                1.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 19818               0.0                    1.0                     0.0
# 14734               1.0                    1.0                     1.0
# 11098               0.0                    1.0                     0.0
# 17360               0.0                    1.0                     1.0
# 13678               0.0                    1.0                     1.0
# 9650                0.0                    1.0                     0.0
# 11341               0.0                    1.0                     0.0
# 10066               0.0                    1.0                     1.0
# 810                 0.0                    0.0                     0.0
# 937                 0.0                    1.0                     0.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 19818                        0.0               1.0                      0.0
# 14734                        1.0               1.0                      1.0
# 11098                        0.0               1.0                      0.0
# 17360                        0.0               1.0                      1.0
# 13678                        1.0               1.0                      1.0
# 9650                         0.0               1.0                      0.0
# 11341                        0.0               1.0                      0.0
# 10066                        1.0               1.0                      1.0
# 810                          0.0               1.0                      0.0
# 937                          0.0               1.0                      0.0
#
#        ...  age_bracket_35 - 44 Years  age_bracket_45 - 54 Years  \
# 19818  ...                          0                          0
# 14734  ...                          0                          0
# 11098  ...                          1                          0
# 17360  ...                          0                          0
# 13678  ...                          0                          0
# 9650   ...                          0                          0
# 11341  ...                          0                          0
# 10066  ...                          0                          1
# 810    ...                          0                          0
# 937    ...                          0                          0
#
#        age_bracket_55 - 64 Years  age_bracket_65+ Years  race_Black  \
# 19818                          1                      0           0
# 14734                          1                      0           0
# 11098                          0                      0           0
# 17360                          0                      1           0
# 13678                          1                      0           0
# 9650                           0                      1           0
# 11341                          0                      1           0
# 10066                          0                      0           0
# 810                            1                      0           0
# 937                            0                      0           0
#
#        race_Hispanic  race_Other or Multiple  race_White sex_Female  sex_Male
# 19818              0                       0           1          1         0
# 14734              0                       0           1          1         0
# 11098              0                       0           1          0         1
# 17360              0                       0           1          1         0
# 13678              1                       0           0          1         0
# 9650               0                       0           1          1         0
# 11341              0                       0           1          1         0
# 10066              0                       1           0          1         0
# 810                0                       1           0          1         0
# 937                0                       0           1          0         1
#
# [10 rows x 33 columns]

# %%
data=pd.get_dummies(data,columns=["census_msa"])
data.sample(10)
# Out:
#        h1n1_worry  h1n1_awareness  antiviral_medication  contact_avoidance  \
# 17763         2.0             0.0                   0.0                1.0
# 4488          0.0             1.0                   0.0                0.0
# 13611         2.0             0.0                   0.0                1.0
# 12989         1.0             1.0                   0.0                1.0
# 11696         2.0             1.0                   1.0                1.0
# 16525         2.0             1.0                   1.0                1.0
# 6830          2.0             0.0                   0.0                1.0
# 4151          3.0             1.0                   0.0                1.0
# 6557          1.0             1.0                   0.0                1.0
# 20810         3.0             2.0                   0.0                1.0
#
#        bought_face_mask  wash_hands_frequently  avoid_large_gatherings  \
# 17763               0.0                    1.0                     0.0
# 4488                0.0                    0.0                     0.0
# 13611               0.0                    1.0                     1.0
# 12989               0.0                    1.0                     0.0
# 11696               0.0                    1.0                     1.0
# 16525               0.0                    1.0                     1.0
# 6830                0.0                    1.0                     1.0
# 4151                0.0                    1.0                     1.0
# 6557                0.0                    1.0                     0.0
# 20810               0.0                    1.0                     0.0
#
#        reduced_outside_home_cont  avoid_touch_face  chronic_medic_condition  \
# 17763                        0.0               1.0                      0.0
# 4488                         0.0               0.0                      0.0
# 13611                        1.0               1.0                      1.0
# 12989                        0.0               1.0                      1.0
# 11696                        1.0               1.0                      0.0
# 16525                        0.0               1.0                      0.0
# 6830                         1.0               1.0                      1.0
# 4151                         0.0               1.0                      1.0
# 6557                         0.0               1.0                      0.0
# 20810                        0.0               1.0                      1.0
#
#        ...  age_bracket_65+ Years  race_Black  race_Hispanic  \
# 17763  ...                      0           0              0
# 4488   ...                      0           0              0
# 13611  ...                      1           0              1
# 12989  ...                      0           0              0
# 11696  ...                      0           1              0
# 16525  ...                      0           0              0
# 6830   ...                      0           0              0
# 4151   ...                      0           0              0
# 6557   ...                      0           1              0
# 20810  ...                      0           0              0
#
#        race_Other or Multiple  race_White  sex_Female  sex_Male  \
# 17763                       0           1           0         1
# 4488                        0           1           0         1
# 13611                       0           0           1         0
# 12989                       1           0           0         1
# 11696                       0           0           1         0
# 16525                       0           1           1         0
# 6830                        0           1           1         0
# 4151                        0           1           1         0
# 6557                        0           0           1         0
# 20810                       0           1           1         0
#
#        census_msa_MSA, Not Principle  City  census_msa_MSA, Principle City  \
# 17763                                    1                               0
# 4488                                     0                               0
# 13611                                    0                               0
# 12989                                    1                               0
# 11696                                    1                               0
# 16525                                    1                               0
# 6830                                     0                               0
# 4151                                     1                               0
# 6557                                     1                               0
# 20810                                    0                               0
#
#        census_msa_Non-MSA
# 17763                   0
# 4488                    1
# 13611                   1
# 12989                   0
# 11696                   0
# 16525                   0
# 6830                    1
# 4151                    0
# 6557                    0
# 20810                   1
#
# [10 rows x 35 columns]

# %%
data["avoid_touch_face"] = data["avoid_touch_face"].fillna(data["avoid_touch_face"].mean())

# %%
data["reduced_outside_home_cont"] = data["reduced_outside_home_cont"].fillna(data["reduced_outside_home_cont"].mean())

# %%
data["avoid_large_gatherings"] = data["avoid_large_gatherings"].fillna(data["avoid_large_gatherings"].mean())

# %%
data["wash_hands_frequently"] = data["wash_hands_frequently"].fillna(data["wash_hands_frequently"].median())

# %%
data["h1n1_worry"] = data["h1n1_worry"].fillna(data["h1n1_worry"].median())

# %%
data["h1n1_awareness"] = data["h1n1_awareness"].fillna(data["h1n1_awareness"].median())

# %%
data["antiviral_medication"] = data["antiviral_medication"].fillna(data["antiviral_medication"].median())

# %%
data["bought_face_mask"] = data["bought_face_mask"].fillna(data["bought_face_mask"].mean())

# %%
data["is_h1n1_vacc_effective"] = data["is_h1n1_vacc_effective"].fillna(data["is_h1n1_vacc_effective"].median())

# %%
data["contact_avoidance"] = data["contact_avoidance"].fillna(data["contact_avoidance"].median())

# %%
data["is_h1n1_vacc_effective"] = data["is_h1n1_vacc_effective"].fillna(data["is_h1n1_vacc_effective"].median())

# %%
data["is_h1n1_risky"] = data["is_h1n1_risky"].fillna(data["is_h1n1_risky"].median())

# %%
data["sick_from_h1n1_vacc"] = data["sick_from_h1n1_vacc"].fillna(data["sick_from_h1n1_vacc"].median())

# %%
data["is_seas_vacc_effective"] = data["is_seas_vacc_effective"].fillna(data["is_seas_vacc_effective"].median())

# %%
data["sick_from_h1n1_vacc"] = data["sick_from_h1n1_vacc"].fillna(data["sick_from_h1n1_vacc"].median())

# %%
data["no_of_adults"] = data["no_of_adults"].fillna(data["no_of_adults"].median())

# %%
data["no_of_children"] = data["no_of_children"].fillna(data["no_of_children"].median())

# %%
data["is_seas_risky"] = data["is_seas_risky"].fillna(data["is_seas_risky"].median())

# %%
data["sick_from_seas_vacc"] = data["sick_from_seas_vacc"].fillna(data["sick_from_seas_vacc"].median())

# %%
data["chronic_medic_condition"] = data["chronic_medic_condition"].fillna(data["chronic_medic_condition"].median())

# %%
data["cont_child_undr_6_mnths"] = data["cont_child_undr_6_mnths"].fillna(data["cont_child_undr_6_mnths"].median())

# %%
data["is_health_worker"] = data["is_health_worker"].fillna(data["is_health_worker"].median())

# %%
data.isnull().sum()
# Out:
# h1n1_worry                             0
# h1n1_awareness                         0
# antiviral_medication                   0
# contact_avoidance                      0
# bought_face_mask                       0
# wash_hands_frequently                  0
# avoid_large_gatherings                 0
# reduced_outside_home_cont              0
# avoid_touch_face                       0
# chronic_medic_condition                0
# cont_child_undr_6_mnths                0
# is_health_worker                       0
# is_h1n1_vacc_effective                 0
# is_h1n1_risky                          0
# sick_from_h1n1_vacc                    0
# is_seas_vacc_effective                 0
# is_seas_risky                          0
# sick_from_seas_vacc                    0
# no_of_adults                           0
# no_of_children                         0
# h1n1_vaccine                           0
# age_bracket_18 - 34 Years              0
# age_bracket_35 - 44 Years              0
# age_bracket_45 - 54 Years              0
# age_bracket_55 - 64 Years              0
# age_bracket_65+ Years                  0
# race_Black                             0
# race_Hispanic                          0
# race_Other or Multiple                 0
# race_White                             0
# sex_Female                             0
# sex_Male                               0
# census_msa_MSA, Not Principle  City    0
# census_msa_MSA, Principle City         0
# census_msa_Non-MSA                     0
# dtype: int64

# %%
data.dtypes
# Out:
# h1n1_worry                             float64
# h1n1_awareness                         float64
# antiviral_medication                   float64
# contact_avoidance                      float64
# bought_face_mask                       float64
# wash_hands_frequently                  float64
# avoid_large_gatherings                 float64
# reduced_outside_home_cont              float64
# avoid_touch_face                       float64
# chronic_medic_condition                float64
# cont_child_undr_6_mnths                float64
# is_health_worker                       float64
# is_h1n1_vacc_effective                 float64
# is_h1n1_risky                          float64
# sick_from_h1n1_vacc                    float64
# is_seas_vacc_effective                 float64
# is_seas_risky                          float64
# sick_from_seas_vacc                    float64
# no_of_adults                           float64
# no_of_children                         float64
# h1n1_vaccine                             int64
# age_bracket_18 - 34 Years                uint8
# age_bracket_35 - 44 Years                uint8
# age_bracket_45 - 54 Years                uint8
# age_bracket_55 - 64 Years                uint8
# age_bracket_65+ Years                    uint8
# race_Black                               uint8
# race_Hispanic                            uint8
# race_Other or Multiple                   uint8
# race_White                               uint8
# sex_Female                               uint8
# sex_Male                                 uint8
# census_msa_MSA, Not Principle  City      uint8
# census_msa_MSA, Principle City           uint8
# census_msa_Non-MSA                       uint8
# dtype: object

# %%
# # Again visualizing after cleaning the data

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.hist(figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'h1n1_worry'}>,
#         <AxesSubplot:title={'center':'h1n1_awareness'}>,
#         <AxesSubplot:title={'center':'antiviral_medication'}>,
#         <AxesSubplot:title={'center':'contact_avoidance'}>,
#         <AxesSubplot:title={'center':'bought_face_mask'}>,
#         <AxesSubplot:title={'center':'wash_hands_frequently'}>],
#        [<AxesSubplot:title={'center':'avoid_large_gatherings'}>,
#         <AxesSubplot:title={'center':'reduced_outside_home_cont'}>,
#         <AxesSubplot:title={'center':'avoid_touch_face'}>,
#         <AxesSubplot:title={'center':'chronic_medic_condition'}>,
#         <AxesSubplot:title={'center':'cont_child_undr_6_mnths'}>,
#         <AxesSubplot:title={'center':'is_health_worker'}>],
#        [<AxesSubplot:title={'center':'is_h1n1_vacc_effective'}>,
#         <AxesSubplot:title={'center':'is_h1n1_risky'}>,
#         <AxesSubplot:title={'center':'sick_from_h1n1_vacc'}>,
#         <AxesSubplot:title={'center':'is_seas_vacc_effective'}>,
#         <AxesSubplot:title={'center':'is_seas_risky'}>,
#         <AxesSubplot:title={'center':'sick_from_seas_vacc'}>],
#        [<AxesSubplot:title={'center':'no_of_adults'}>,
#         <AxesSubplot:title={'center':'no_of_children'}>,
#         <AxesSubplot:title={'center':'h1n1_vaccine'}>,
#         <AxesSubplot:title={'center':'age_bracket_18 - 34 Years'}>,
#         <AxesSubplot:title={'center':'age_bracket_35 - 44 Years'}>,
#         <AxesSubplot:title={'center':'age_bracket_45 - 54 Years'}>],
#        [<AxesSubplot:title={'center':'age_bracket_55 - 64 Years'}>,
#         <AxesSubplot:title={'center':'age_bracket_65+ Years'}>,
#         <AxesSubplot:title={'center':'race_Black'}>,
#         <AxesSubplot:title={'center':'race_Hispanic'}>,
#         <AxesSubplot:title={'center':'race_Other or Multiple'}>,
#         <AxesSubplot:title={'center':'race_White'}>],
#        [<AxesSubplot:title={'center':'sex_Female'}>,
#         <AxesSubplot:title={'center':'sex_Male'}>,
#         <AxesSubplot:title={'center':'census_msa_MSA, Not Principle  City'}>,
#         <AxesSubplot:title={'center':'census_msa_MSA, Principle City'}>,
#         <AxesSubplot:title={'center':'census_msa_Non-MSA'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# ## Modelling

# %%
X = data.drop(["h1n1_vaccine"], axis=1)
#dependent variable
Y= data[["h1n1_vaccine"]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2,random_state=2)

# %%
# ### LogisticRegression

# %%
lrc = LogisticRegression()
lrc.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lrc.score(X_train, Y_train)
# Out:
# 0.815399017084016

# %%
lrc.score(X_test, Y_test)
# Out:
# 0.8109322351179333

# %%
# ### LogisticRegression with Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
lrc.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
lrc.score(X_train, Y_train)
# Out:
# 0.8154458226070677

# %%
lrc.score(X_test, Y_test)
# Out:
# 0.8111194309247473

# %%
# ### Naive bayes

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
gnb.score(X_test,Y_test)
# Out:
# 0.752527143391988

# %%
scaler_1= StandardScaler()
X_train=scaler_1.fit_transform(X_train)
X_test=scaler_1.fit_transform(X_test)

# %%
gnb.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
gnb.score(X_train,Y_train)
# Out:
# 0.7427568453077463

# %%
gnb.score(X_test,Y_test)
# Out:
# 0.752527143391988

# %%
bnb.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BernoulliNB()

# %%
bnb.score(X_test,Y_test)
# Out:
# 0.7742418569824036

# %%
bnb.score(X_train,Y_train)
# Out:
# 0.7713550198923473

# %%
scaler_2= StandardScaler()
X_train=scaler_2.fit_transform(X_train)
X_test=scaler_2.fit_transform(X_test)

# %%
bnb.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BernoulliNB()

# %%
bnb.score(X_train,Y_train)
# Out:
# 0.7713550198923473

# %%
bnb.score(X_test,Y_test)
# Out:
# 0.7742418569824036

# %%
# ### Support Vector Machine

# %%
svc =SVC(kernel='sigmoid', gamma=1.0)

# %%
svc.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(gamma=1.0, kernel='sigmoid')

# %%
svc.score(X_train,Y_train)
# Out:
# 0.7111163117247835

# %%
svc.score(X_test,Y_test)
# Out:
# 0.7109696742792961

# %%
# ### KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn.score(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.8384273344254622

# %%
knn.score(X_test,Y_test)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.7815424934481467

# %%
# ### DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier(max_depth=4, random_state=2)

# %%
dtc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=2)

# %%
dtc.score(X_train,Y_train)
# Out:
# 0.8132927685466885

# %%
dtc.score(X_test,Y_test)
# Out:
# 0.8101834518906776

# %%
# ### BaggingClassifier

# %%
bc = BaggingClassifier(n_estimators=50,max_samples=1000, n_jobs=5)

# %%
bc.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:719: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BaggingClassifier(max_samples=1000, n_estimators=50, n_jobs=5)

# %%
bc.score(X_train,Y_train)
# Out:
# 0.8279428972618769

# %%
bc.score(X_test,Y_test)
# Out:
# 0.8109322351179333

# %%
# ### AdaBoostClassifier

# %%
abc= AdaBoostClassifier(n_estimators=50, random_state=2)

# %%
abc.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostClassifier(random_state=2)

# %%
abc.score(X_train,Y_train)
# Out:
# 0.8149309618534987

# %%
abc.score(X_test,Y_test)
# Out:
# 0.8099962560838637

# %%
# ### RandomForestClassifier

# %%
rfc= RandomForestClassifier(max_samples=1000,random_state=3)

# %%
rfc.fit(X_train,Y_train)
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_3592\1022771658.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(X_train,Y_train)
# RandomForestClassifier(max_samples=1000, random_state=3)

# %%
rfc.score(X_train,Y_train)
# Out:
# 0.8246197051252048

# %%
rfc.score(X_test,Y_test)
# Out:
# 0.8105578435043055

# %%
# ### GradientBoostingClassifier

# %%
gbdt= GradientBoostingClassifier(random_state=2,n_estimators=50)

# %%
gbdt.fit(X_train,Y_train)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier(n_estimators=50, random_state=2)

# %%
gbdt.score(X_train,Y_train)
# Out:
# 0.8190966534051018

# %%
gbdt.score(X_test,Y_test)
# Out:
# 0.8167353051291651

# %%
# ## Now finding Accuracy and Precision

# %%
clfs = {
 'SVC' : svc,
    'KN' : knn,
    'BN' : bnb,
    'GB': gnb,
    'DT' : dtc,
    'LR' : lrc,
    'RF' : rfc,
    'AdaBoost' : abc,
    'BgC': bc,
    'GBDT':gbdt,
    
    
}

# %%
def train_classifier(clf,X_train,X_test,Y_train,Y_test):
    clf.fit(X_train,Y_train)
    Y_pred = clf.predict(X_test)
    accuracy= accuracy_score(Y_test,Y_pred)
    precision= precision_score(Y_test,Y_pred)
    
    return accuracy,precision

# %%
accuracy_scores= []
precision_scores=[]

for name,clf in clfs.items():
      
    current_accuracy,current_precision = train_classifier(clf,X_train,X_test,Y_train,Y_test)
        
    print('For ', name)
    print('Accuracy - ', current_accuracy)
    print('Precision - ',current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# For  SVC
# Accuracy -  0.7109696742792961
# Precision -  0.33535528596187175
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# For  KN
# Accuracy -  0.7815424934481467
# Precision -  0.4971857410881801
# For  BN
# Accuracy -  0.7742418569824036
# Precision -  0.48151408450704225
# For  GB
# Accuracy -  0.752527143391988
# Precision -  0.44544198895027626
# For  DT
# Accuracy -  0.8101834518906776
# Precision -  0.6233552631578947
# For  LR
# Accuracy -  0.8111194309247473
# Precision -  0.6504854368932039
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\santh\AppData\Local\Temp\ipykernel_3592\1171014256.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train,Y_train)
# For  RF
# Accuracy -  0.8105578435043055
# Precision -  0.740506329113924
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# For  AdaBoost
# Accuracy -  0.8099962560838637
# Precision -  0.6286701208981001
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\ensemble\_bagging.py:719: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# For  BgC
# Accuracy -  0.811681018345189
# Precision -  0.6702586206896551
# C:\Users\santh\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# For  GBDT
# Accuracy -  0.8167353051291651
# Precision -  0.6876267748478702

# %%
performance_df =pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 6        RF  0.810558   0.740506
# 9      GBDT  0.816735   0.687627
# 8       BgC  0.811681   0.670259
# 5        LR  0.811119   0.650485
# 7  AdaBoost  0.809996   0.628670
# 4        DT  0.810183   0.623355
# 1        KN  0.781542   0.497186
# 2        BN  0.774242   0.481514
# 3        GB  0.752527   0.445442
# 0       SVC  0.710970   0.335355

# %% [markdown]
# ##### # Hence Random Forest gives higher Acuuracy and precision than other algorithms
